# %%
import pandas 
import urllib.request, urllib.parse
import json

source_csv = pandas.read_csv("~/Downloads/flvoters_statewide_latsandlongs_found_copy.csv", sep="\t")

# %%
from json_extract import flatten_json
import requests
from tabulate import tabulate
import math 
import numpy

count = 0
missing = 0
successful = 0

source_csv['latlong_found'] = source_csv['latitude']
source_csv['latlong_found'] = numpy.where(pandas.isna(source_csv.latitude),'N', 'Y')

print(tabulate(source_csv.groupby(['latlong_found', 'removed']).size().reset_index().rename(columns={0:'count'}), headers='keys', tablefmt='psql', showindex=False))

print("processing...")
for index, row in source_csv.iterrows():
    if str(row['api_failed_to_resolve']) == "Y":
        continue    # we have previously tried to request this and it was unable to be resolved 
    if count == 49950:
        break   # reached our daily limit
    if (str(row['removed']) == 'N' and pandas.isna(row['latitude'])):
        adminDistrict = "FL"
           
        postalCode = str(int(row['res_zipcode'])) if not pandas.isna(row['res_zipcode']) else '-'

        locality = str(row['res_city']) if not pandas.isna(row['res_city']) else '-'

        address = str(row['res_street_address_line_1']) + " " + str(row['res_street_address_line_2'])
        addressLine = address if address else '-'

        maxResults = 1

        BingMapsAPIKey = ""
         
        

        # You can substitute a hyphen (-) for any structured URL parameter when there is no value.
        
        url_header = f'http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict={adminDistrict}&locality={locality}&postalCode={postalCode}&addressLine={addressLine}&maxResults={maxResults}&key={BingMapsAPIKey}'

        # url_header_encoded = urllib.parse.quote(url_header)
        #  print(url_header)
        
        response = requests.get(url_header)
        count += 1

        if response.status_code == 200:
            successful += 1
            coords = flatten_json(response.json())
            latitude = coords['resourceSets_0_resources_0_point_coordinates_0']
            longitude = coords['resourceSets_0_resources_0_point_coordinates_1']
            # print(str(latitude) + ", " + str(longitude))
            source_csv.loc[index, 'latitude'] = latitude
            source_csv.loc[index, 'longitude'] = longitude
            source_csv.loc[index, 'api_failed_to_resolve'] = "N"
            source_csv.loc[index, 'geolocation_source'] = "bing"
        else:
            missing += 1
            source_csv.loc[index, 'api_failed_to_resolve'] = "Y"

source_csv['latlong_found_after'] = source_csv['latitude']
source_csv['latlong_found_after'] = numpy.where(pandas.isna(source_csv.latitude),'N', 'Y')

print(tabulate(source_csv.groupby(['latlong_found', 'latlong_found_after', 'removed']).size().reset_index().rename(columns={0:'count'}), headers='keys', tablefmt='psql', showindex=False))

if successful == 0:
    # We have finished all the missing entries for this sheet
    print("Finished all possible entries in sheet")

# source_csv.to_csv("~/Downloads/ncvoter_statewide_latsandlons (copy).csv", mode='w', header=True, sep='\t', index=False)
# Out:
# +-----------------+-----------+---------+
# | latlong_found   | removed   |   count |
# |-----------------+-----------+---------|
# | N               | N         | 2179740 |
# | N               | Y         |  851288 |
# | Y               | N         | 5027189 |
# +-----------------+-----------+---------+
# processing...
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=ELON&postalCode=27244&addressLine=525 E PHOENIX DR   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.1079611576862, -79.505039537633
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=ELON&postalCode=27244&addressLine=27  HOLMESWAY    &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.1077847, -79.5154559
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=ELON&postalCode=27244&addressLine=27  HOLMESWAY    &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.1077847, -79.5154559
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=GRAHAM&postalCode=27253&addressLine=620  BANKS ST   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.06671730746578, -79.4111496935687
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=314  TRAIL THREE    &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.075041, -79.459985
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=MEBANE&postalCode=27302&addressLine=102  VILLAGE DR   #516&maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=MEBANE&postalCode=27302&addressLine=2923  HEATHER RD   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.026466, -79.283201
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27217&addressLine=4955  SARTIN RD   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.23144762406172, -79.43664169175173
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=MEBANE&postalCode=27302&addressLine=1705  WILLOW BROOK CT   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.0675868, -79.2942362
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=MEBANE&postalCode=27302&addressLine=104  BAYHILL CT   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.128028, -79.26156
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=MEBANE&postalCode=27302&addressLine=1705  WILLOW BROOK CT   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.0675868, -79.2942362
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=2006  TRAIL TWO    #7J&maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=ELON&postalCode=27244&addressLine=2519  BRIDGE VIEW RD   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 35.57230887404077, -79.88713289661888
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=GRAHAM&postalCode=27253&addressLine=3355  NC HWY 54    &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.017152, -79.328157
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=3551  FORESTDALE DR   #RK&maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27217&addressLine=2457  WILLIE PACE RD   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.227354428566954, -79.30228011286523
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=1910 S MEBANE ST   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.072989, -79.456556
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=1910 S MEBANE ST   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.072989, -79.456556
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=ELON&postalCode=27244&addressLine=525 E PHOENIX DR   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.1079611576862, -79.505039537633
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=MEBANE&postalCode=27302&addressLine=511 E STAGECOACH RD   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.1080935, -79.2613182
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=2607  SUMAC LN   &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.07137120078923, -79.47429316428016
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=915  TRAIL EIGHT    &maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# 36.0681998, -79.4499214
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=760  BOONE STATION DR   #A&maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# http://dev.virtualearth.net/REST/v1/Locations/?countryRegion=US&adminDistrict=NC&locality=BURLINGTON&postalCode=27215&addressLine=710  BOONE STATION DR   #K&maxResults=1&key=AiletFtOCnCflFXzOAtjjANkydSsoC04bcpDaJrT8M13ZcKQ-bYl1Z_Ee3YLDe-Q
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-56d30982c2b5> in <module>
#      53             source_csv.loc[index, 'api_failed_to_resolve'] = "N"
#      54         else:
# ---> 55             source_csv.loc[index, 'api_failed_to_resolve'] = "Y"
#      56
#      57 source_csv['latlong_found_after'] = source_csv['latitude']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1763                 # scalar value
#    1764                 for loc in ilocs:
# -> 1765                     isetter(loc, value)
#    1766
#    1767         else:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in isetter(loc, v)
#    1688                 else:
#    1689                     # set the item, possibly having a dtype change
# -> 1690                     ser = ser.copy()
#    1691                     ser._mgr = ser._mgr.setitem(indexer=pi, value=v)
#    1692                     ser._maybe_update_cacher(clear=True)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in copy(self, deep)
#    5658         dtype: object
#    5659         """
# -> 5660         data = self._mgr.copy(deep=deep)
#    5661         self._clear_item_cache()
#    5662         return self._constructor(data).__finalize__(self, method="copy")
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in copy(self, deep)
#     800             new_axes = list(self.axes)
#     801
# --> 802         res = self.apply("copy", deep=deep)
#     803         res.axes = new_axes
#     804         return res
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in copy(self, deep)
#     676         values = self.values
#     677         if deep:
# --> 678             values = values.copy()
#     679         return self.make_block_same_class(values, ndim=self.ndim)
#     680
#
# KeyboardInterrupt:
